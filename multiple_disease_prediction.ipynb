# %%
import pandas as pd
parkinsons_df = pd.read_csv(r"E:\User\Desktop\sham\DATA SCIENCE\PROJECTS\Project3 - Multiple Disease Prediction\files\parkinsons - parkinsons.csv")
#Display the preview of the parkinsons dataset.
parkinsons_df.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
#To get the statistical values of the dataset.
parkinsons_df.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# ...

# %%
#Display the information about the dataset like non-null count,data type of the column
parkinsons_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
# ...

# %%
#check the null/missing values for each column
parkinsons_df.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
import pandas as pd
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
parkinsons_df = pd.read_csv(r"E:\User\Desktop\sham\DATA SCIENCE\PROJECTS\Project3 - Multiple Disease Prediction\files\parkinsons - parkinsons.csv")
feature = parkinsons_df.drop(columns=['name','status'], axis=1)
target = parkinsons_df['status']
# Set up the plot
plt.figure(figsize=(10, 6))

# Loop over all columns in the feature
for column in feature:
    sns.boxplot(y=parkinsons_df[column], label=column)
    plt.legend()
    plt.show()

# Show the plot
plt.title("Boxplot for all columns")
# Out:
# Text(0.5, 1.0, 'Boxplot for all columns')

# %%
#Find correlation between columns using heat map
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize = (20,20))
#Drop unwanted columns
feature = parkinsons_df.drop(columns=['name','status'])
sns.heatmap(feature.corr(), annot = True, fmt=".2f",linewidths=0.5)
# Out:
# <Axes: >

# %%
#Visualize Class distribution
import pandas as pd
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
parkinsons_df = pd.read_csv(r"E:\User\Desktop\sham\DATA SCIENCE\PROJECTS\Project3 - Multiple Disease Prediction\files\parkinsons - parkinsons.csv")
target = parkinsons_df['status']
# Plot a countplot to visualize class distribution
sns.countplot(x=target)
plt.title('Class Distribution')
plt.xlabel('Class')
plt.ylabel('Count')
plt.show()

# %%
#### KIDNEY DISEASE PREDICTION ########

# %%
import pandas as pd
kidney_df = pd.read_csv(r"E:\User\Desktop\sham\DATA SCIENCE\PROJECTS\Project3 - Multiple Disease Prediction\files\kidney_disease - kidney_disease.csv")
#Preview of the dataset
kidney_df.head()
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#    ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0  ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1  ...   38  6000  NaN   no   no   no  good   no   no            ckd
# 2  ...   31  7500  NaN   no  yes   no  poor   no  yes            ckd
# 3  ...   32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4  ...   35  7300  4.6   no   no   no  good   no   no            ckd
#
# [5 rows x 26 columns]

# %%
kidney_df.shape
# Out:
# (400, 26)

# %%
#To get the statistical values of the dataset.
kidney_df.describe()
# Out:
#                id         age          bp          sg          al          su  \
# count  400.000000  391.000000  388.000000  353.000000  354.000000  351.000000
# mean   199.500000   51.483376   76.469072    1.017408    1.016949    0.450142
# std    115.614301   17.169714   13.683637    0.005717    1.352679    1.099191
# min      0.000000    2.000000   50.000000    1.005000    0.000000    0.000000
# 25%     99.750000   42.000000   70.000000    1.010000    0.000000    0.000000
# 50%    199.500000   55.000000   80.000000    1.020000    0.000000    0.000000
# 75%    299.250000   64.500000   80.000000    1.020000    2.000000    0.000000
# max    399.000000   90.000000  180.000000    1.025000    5.000000    5.000000
#
#               bgr          bu          sc         sod         pot        hemo
# count  356.000000  381.000000  383.000000  313.000000  312.000000  348.000000
# mean   148.036517   57.425722    3.072454  137.528754    4.627244   12.526437
# ...

# %%
#Display the information about the dataset like non-null count,data type of the column
kidney_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              400 non-null    int64
#  1   age             391 non-null    float64
#  2   bp              388 non-null    float64
#  3   sg              353 non-null    float64
#  4   al              354 non-null    float64
#  5   su              351 non-null    float64
#  6   rbc             248 non-null    object
#  7   pc              335 non-null    object
#  8   pcc             396 non-null    object
#  9   ba              396 non-null    object
#  10  bgr             356 non-null    float64
#  11  bu              381 non-null    float64
#  12  sc              383 non-null    float64
#  13  sod             313 non-null    float64
#  14  pot             312 non-null    float64
#  15  hemo            348 non-null    float64
#  16  pcv             330 non-null    object
# ...

# %%
#check the null/missing values for each column
kidney_df.isnull().sum()
# Out:
# id                  0
# age                 9
# bp                 12
# sg                 47
# al                 46
# su                 49
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# bgr                44
# bu                 19
# sc                 17
# sod                87
# pot                88
# hemo               52
# pcv                70
# wc                105
# rc                130
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %%
#Drop unwanted columns
kidney_df.drop(columns=['id','age'])
# Out:
#        bp     sg   al   su       rbc        pc         pcc          ba    bgr  \
# 3    70.0  1.005  4.0  0.0    normal  abnormal     present  notpresent  117.0
# 9    90.0  1.020  2.0  0.0  abnormal  abnormal     present  notpresent   70.0
# 11   70.0  1.010  3.0  0.0  abnormal  abnormal     present  notpresent  380.0
# 14   80.0  1.010  3.0  2.0    normal  abnormal     present     present  157.0
# 20   80.0  1.015  2.0  0.0  abnormal  abnormal  notpresent  notpresent  173.0
# ..    ...    ...  ...  ...       ...       ...         ...         ...    ...
# 395  80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent  140.0
# 396  70.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent   75.0
# 397  80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent  100.0
# 398  60.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent  114.0
# 399  80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent  131.0
#
# ...

# %%
### Identify outliers using boxplot ###
import pandas as pd
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
feature = kidney_df.drop(columns=['id','age','classification'], axis=1)
target = kidney_df['classification']
# Set up the plot
plt.figure(figsize=(10, 6))

# Loop over all columns in the feature
for column in feature:
    sns.boxplot(y=kidney_df[column], label=column)
    plt.legend()
    plt.show()

# Show the plot
plt.title("Boxplot for all columns")
# Out:
# Text(0.5, 1.0, 'Boxplot for all columns')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

y = kidney_df['classification']
sns.countplot(x=y)
plt.title('Class Distribution')
plt.xlabel('Class')
plt.ylabel('Count')
plt.show()

# %%
###### Indian Liver Patient Prediction ####44

# %%
import pandas as pd
liver_patient_df = pd.read_csv(r"E:\User\Desktop\sham\DATA SCIENCE\PROJECTS\Project3 - Multiple Disease Prediction\files\indian_liver_patient - indian_liver_patient.csv")
#Preview of the dataset
liver_patient_df.head()
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65  Female              0.7               0.1                   187
# 1   62    Male             10.9               5.5                   699
# 2   62    Male              7.3               4.1                   490
# 3   58    Male              1.0               0.4                   182
# 4   72    Male              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0      3.3                        0.90        1
# ...

# %%
#Display the Total number of rows and columns
liver_patient_df.shape
# Out:
# (583, 11)

# %%
#To get the statistical values of the dataset.
liver_patient_df.describe()
# Out:
#               Age  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# count  583.000000       583.000000        583.000000            583.000000
# mean    44.746141         3.298799          1.486106            290.576329
# std     16.189833         6.209522          2.808498            242.937989
# min      4.000000         0.400000          0.100000             63.000000
# 25%     33.000000         0.800000          0.200000            175.500000
# 50%     45.000000         1.000000          0.300000            208.000000
# 75%     58.000000         2.600000          1.300000            298.000000
# max     90.000000        75.000000         19.700000           2110.000000
#
#        Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# count                583.000000                  583.000000      583.000000
# mean                  80.713551                  109.910806        6.483190
# ...

# %%
#Display the information about the dataset like non-null count,data type of the column
liver_patient_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         583 non-null    int64
#  1   Gender                      583 non-null    object
#  2   Total_Bilirubin             583 non-null    float64
#  3   Direct_Bilirubin            583 non-null    float64
#  4   Alkaline_Phosphotase        583 non-null    int64
#  5   Alamine_Aminotransferase    583 non-null    int64
#  6   Aspartate_Aminotransferase  583 non-null    int64
#  7   Total_Protiens              583 non-null    float64
#  8   Albumin                     583 non-null    float64
#  9   Albumin_and_Globulin_Ratio  579 non-null    float64
#  10  Dataset                     583 non-null    int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 50.2+ KB

# %%
#check the null/missing values for each column
liver_patient_df.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    4
# Dataset                       0
# dtype: int64

# %%
### Identify outliers using boxplot ###
import matplotlib.pyplot as plt
import seaborn as sns
feature = liver_patient_df.drop(columns=['Gender'], axis=1)
target = liver_patient_df['Dataset']
# Set up the plot
plt.figure(figsize=(10, 6))

# Loop over all columns in the feature
for column in feature:
    sns.boxplot(y=liver_patient_df[column], label=column)
    plt.legend()
    plt.show()

# Show the plot
plt.title("Boxplot for all columns")
# Out:
# Text(0.5, 1.0, 'Boxplot for all columns')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
target = liver_patient_df['Dataset']

# Plot a countplot to visualize class distribution
sns.countplot(x=target)
plt.title('Class Distribution')
plt.xlabel('Class')
plt.ylabel('Count')
plt.show()
